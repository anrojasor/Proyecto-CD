# %%
#pip install pandasai

# %%
import os
import pandas as pd
from pandasai import PandasAI
from pandasai import SmartDataframe
import matplotlib
from pandasai.callbacks import BaseCallback, StdoutCallback

# %%
# OpenAI
from pandasai.llm import OpenAI
llm = OpenAI(api_token="key")

# %%
#Leer datos desde una hoja de excel y seleccionando la hoja
df = pd.read_excel('../datos//Base_proyecto_1.xlsx', sheet_name='Hoja1')
#Establecer la fecha como indice
df = df.set_index('Fecha')
#Cambiar el formato a fecha del indice
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#             ICE Brent 01M  NYMEX WTI 01M  NYMEX Heating Oil 01M  \
# Fecha
# 2018-01-02          66.57            NaN                 2.0584
# 2018-01-03          67.84            NaN                 2.0880
# 2018-01-04          68.07            NaN                 2.0770
# 2018-01-05          67.62            NaN                 2.0587
# 2018-01-08          67.78            NaN                 2.0454
#
#             NYMEX RBOB 01M  NYMEX Natural Gas 01M
# Fecha
# 2018-01-02             NaN                  3.056
# 2018-01-03             NaN                  3.008
# 2018-01-04             NaN                  2.880
# 2018-01-05             NaN                  2.795
# 2018-01-08             NaN                  2.835

# %%
#df = SmartDataframe(df, config={"llm": llm}, {"callback": StdoutCallback()})
df = SmartDataframe(df, {"callback": StdoutCallback()}, config={"llm": llm})

# %%
df.chat('Show a plot for ICE Brent 01M')

# %%
df.chat('drop the second and the fourth colums')
# Out:
# Traceback (most recent call last):
#   File "C:\Users\anroj\anaconda3\envs\pandasai\Lib\site-packages\pandasai\smart_datalake\__init__.py", line 314, in chat
#     result = self._code_manager.execute_code(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anroj\anaconda3\envs\pandasai\Lib\site-packages\pandasai\helpers\code_manager.py", line 199, in execute_code
#     return analyze_data(self._get_original_dfs())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 3, in analyze_data
#   File "C:\Users\anroj\anaconda3\envs\pandasai\Lib\site-packages\pandas\util\_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anroj\anaconda3\envs\pandasai\Lib\site-packages\pandas\core\frame.py", line 5399, in drop
#     return super().drop(
#            ^^^^^^^^^^^^^
#   File "C:\Users\anroj\anaconda3\envs\pandasai\Lib\site-packages\pandas\util\_decorators.py", line 331, in wrapper
# ...

# %%
df.chat('show only the first column')
# Out:
#             ICE Brent 01M
# Fecha
# 2018-01-02          66.57
# 2018-01-03          67.84
# 2018-01-04          68.07
# 2018-01-05          67.62
# 2018-01-08          67.78
# ...                   ...
# 2023-03-21          75.32
# 2023-03-22          76.69
# 2023-03-23          75.91
# 2023-03-24          74.99
# 2023-03-27          78.12
#
# [1352 rows x 1 columns]

# %%
df.chat('show a plot of 2020')
# Out:
# <string>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.chat('Crea un gráfico únicamente para ICE Brent 01M y únicamente para el año 2020')

# %%
df.chat('Crea un gráfico de autocorrelación para ICE Brent 01M usando pandas.plotting.autocorrelation_plot')
